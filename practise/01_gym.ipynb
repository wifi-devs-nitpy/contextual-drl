# %%
import gymnasium as gym
from reinforced_lib import RLib

env = gym.make("CartPole-v1")

# %%
print(env)
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v1>>>>>

# %%
observation, info = env.reset()
print(observation, info)
# Out:
# [-0.00909774 -0.04405244 -0.02493108  0.00528953] {}

# %%
observation, reward, terminated, truncated, info = env.step(1)
print(observation, reward, terminated, truncated, info)
# Out:
# [-1.2732554e-05  5.4242313e-01 -4.2639606e-02 -8.9776355e-01] 1.0 False False {}

# %%
import inspect 
print(inspect.signature(RLib))
# Out:
# (*, agent_type: type = None, agent_params: dict[str, any] = None, ext_type: type = None, ext_params: dict[str, any] = None, logger_types: Union[type, list[type]] = None, logger_sources: Union[tuple[str, reinforced_lib.logs.base_logger.SourceType], str, NoneType, list[Union[tuple[str, reinforced_lib.logs.base_logger.SourceType], str, NoneType]]] = None, logger_params: dict[str, any] = None, no_ext_mode: bool = False, auto_checkpoint: int = None, auto_checkpoint_path: str = None) -> None
