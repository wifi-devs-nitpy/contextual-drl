# %%
import jax.numpy as jnp 
a = jnp.arrayt([1, 3, 4, 5, 6, 7, 8])

jnp.random.choice(a)
# Out:
# Running cells with 'macp-cmab (3.13.5) (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '//curiousbalu/Users/studi/Documents/Electronics/wireless_networks/wifi-9/simulations/mapc-cmab/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
