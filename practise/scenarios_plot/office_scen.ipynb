# %%
sc.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sc.plot()
#
# NameError: name 'sc' is not defined

# %%
sc2 = enterprise_scenario(seed=24, x_offices=2, y_offices=2, x_cubicles=4, y_cubicles=4, n_sta_per_cubicle=2, n_cubicle_per_ap=8, n_ap_per_office=2, size_office=30, size_cubicle=2)

# %%
sc2.plot()
