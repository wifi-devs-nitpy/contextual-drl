# %%
import pandas as pd 
import json

# %%
path = "C:/Users/studi/Documents/Electronics/wireless_networks/wifi-9/simulations/mapc-cmab/tests/logs/static_small_office_10.0_2.0/run_7.json"

# %%
import pandas as pd

# %%
df = pd.read_json(path)
df[df["reward"] > 1700]
# Out:
#       run  step              link_indices                ap_indices  \
# 2021    7  2022        [0, 0, 1, 1, 2, 2]        [2, 3, 2, 3, 1, 3]
# 2478    7  2479  [0, 0, 0, 1, 1, 1, 2, 2]  [1, 2, 3, 1, 2, 3, 1, 3]
# 3342    7  3343        [0, 0, 1, 1, 2, 2]        [2, 3, 2, 3, 1, 3]
# 4053    7  4054  [0, 0, 0, 1, 1, 1, 2, 2]  [0, 2, 3, 0, 2, 3, 0, 3]
# 4180    7  4181     [0, 0, 1, 1, 2, 2, 2]     [1, 3, 1, 3, 1, 2, 3]
# 4196    7  4197  [0, 0, 0, 1, 1, 1, 2, 2]  [1, 2, 3, 1, 2, 3, 1, 3]
# 4269    7  4270  [0, 0, 0, 1, 1, 1, 2, 2]  [1, 2, 3, 1, 2, 3, 1, 3]
# 4277    7  4278     [0, 0, 0, 1, 1, 1, 2]     [0, 2, 3, 0, 2, 3, 3]
# 4306    7  4307  [0, 0, 1, 1, 1, 2, 2, 2]  [2, 3, 0, 2, 3, 0, 2, 3]
# 4910    7  4911     [0, 0, 0, 1, 1, 1, 2]     [0, 2, 3, 0, 2, 3, 3]
# 4918    7  4919  [0, 0, 0, 1, 1, 1, 2, 2]  [1, 2, 3, 1, 2, 3, 1, 3]
# 4978    7  4979                    [0, 1]                    [2, 2]
#
#                        station_indices          tx_power_indices       reward
# ...
